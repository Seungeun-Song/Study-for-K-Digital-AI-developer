# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/datasets/pa_mark/

# %%
import os 

file_path = "/content/drive/MyDrive/Colab Notebooks/datasets/pa_mark"
file_names = os.listdir(file_path)
file_names
# Out:
# ['_0_2921.jpg',
#  '_0_2920.txt',
#  '_0_2921.txt',
#  '_0_2913.jpg',
#  '_0_290.jpg',
#  '_0_2920.jpg',
#  '_0_290.txt',
#  '_0_2895.txt',
#  '_0_292.jpg',
#  '_0_2913.txt',
#  '_0_292.txt',
#  '_0_2894.txt',
#  '_0_2869.txt',
#  '_0_2845.txt',
#  '_0_2863.txt',
#  '_0_2849.txt',
#  '_0_2887.txt',
#  '_0_2895.jpg',
#  '_0_2849.jpg',
#  '_0_2835.txt',
#  '_0_2840.txt',
#  '_0_2833.txt',
#  '_0_2816.txt',
#  '_0_2831.txt',
#  '_0_2894.jpg',
#  '_0_2887.jpg',
#  '_0_2863.jpg',
#  '_0_2869.jpg',
#  '_0_2845.jpg',
#  '_0_2843.txt',
#  '_0_2840.jpg',
#  '_0_2833.jpg',
#  '_0_2835.jpg',
#  '_0_2831.jpg',
#  '_0_2797.txt',
#  '_0_2800.txt',
#  '_0_2795.txt',
#  '_0_2812.txt',
#  '_0_2843.jpg',
#  '_0_2816.jpg',
#  '_0_2792.txt',
#  '_0_2752.txt',
#  '_0_2767.txt',
#  '_0_2773.txt',
#  '_0_277.txt',
#  '_0_2812.jpg',
#  '_0_2795.jpg',
#  '_0_2797.jpg',
#  '_0_2800.jpg',
#  '_0_2792.jpg',
#  '_0_2684.jpg',
#  '_0_2728.jpg',
#  '_0_2663.txt',
#  '_0_2657.txt',
#  '_0_267.txt',
# ...

# %%
changed_path = "/content/drive/MyDrive/Colab Notebooks/datasets/pa"
for name in file_names:
  ori = os.path.join(file_path, name)
  cha = 'pa'+name
  cha = os.path.join(changed_path, cha)
  os.rename(ori, cha)

# %%
import pandas as pd

txt_name = '/content/pa.txt'
df =pd.read_csv(txt_name)
df.head()
# Out:
#     x64/Release/data/img/_0_100.jpg
# 0  x64/Release/data/img/_0_1003.jpg
# 1  x64/Release/data/img/_0_1013.jpg
# 2  x64/Release/data/img/_0_1017.jpg
# 3   x64/Release/data/img/_0_102.jpg
# 4  x64/Release/data/img/_0_1028.jpg

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df_list = df.values.tolist()
print(type(df_list))
# Out:
# <class 'list'>

# %%
#print(str(df[0]).replace('img/','img/pa'))
# Out:
# ['x64/Release/data/img/pa_0_1003.jpg']

# %%
a=[]
for n in range(848):
  change = str(df_list[n]).replace('img/','img/pa')
  a.append(change)
print(a)
# Out:
# ["['x64/Release/data/img/pa_0_1003.jpg']", "['x64/Release/data/img/pa_0_1013.jpg']", "['x64/Release/data/img/pa_0_1017.jpg']", "['x64/Release/data/img/pa_0_102.jpg']", "['x64/Release/data/img/pa_0_1028.jpg']", "['x64/Release/data/img/pa_0_1033.jpg']", "['x64/Release/data/img/pa_0_1038.jpg']", "['x64/Release/data/img/pa_0_1050.jpg']", "['x64/Release/data/img/pa_0_1061.jpg']", "['x64/Release/data/img/pa_0_1084.jpg']", "['x64/Release/data/img/pa_0_1087.jpg']", "['x64/Release/data/img/pa_0_1093.jpg']", "['x64/Release/data/img/pa_0_1118.jpg']", "['x64/Release/data/img/pa_0_1136.jpg']", "['x64/Release/data/img/pa_0_1137.jpg']", "['x64/Release/data/img/pa_0_1138.jpg']", "['x64/Release/data/img/pa_0_1146.jpg']", "['x64/Release/data/img/pa_0_1147.jpg']", "['x64/Release/data/img/pa_0_1183.jpg']", "['x64/Release/data/img/pa_0_1184.jpg']", "['x64/Release/data/img/pa_0_1192.jpg']", "['x64/Release/data/img/pa_0_1204.jpg']", "['x64/Release/data/img/pa_0_1228.jpg']", "['x64/Release/data/img/pa_0_123
# ...

# %%
print(len(a))
print(type(a))
# Out:
# 848
# <class 'list'>

# %%
b = ''.join(a)
print(len(b))
print(b)

# %%
f_path = '/content/file.txt'

for n in a:
  output = ''.join(n)
  print(output)
  # with open(f_path, 'w') as output:
  #   for row in a:
  #     output.write(str(row)+'\n')
# Out:
# ['x64/Release/data/img/pa_0_1003.jpg']
# ['x64/Release/data/img/pa_0_1013.jpg']
# ['x64/Release/data/img/pa_0_1017.jpg']
# ['x64/Release/data/img/pa_0_102.jpg']
# ['x64/Release/data/img/pa_0_1028.jpg']
# ['x64/Release/data/img/pa_0_1033.jpg']
# ['x64/Release/data/img/pa_0_1038.jpg']
# ['x64/Release/data/img/pa_0_1050.jpg']
# ['x64/Release/data/img/pa_0_1061.jpg']
# ['x64/Release/data/img/pa_0_1084.jpg']
# ['x64/Release/data/img/pa_0_1087.jpg']
# ['x64/Release/data/img/pa_0_1093.jpg']
# ['x64/Release/data/img/pa_0_1118.jpg']
# ['x64/Release/data/img/pa_0_1136.jpg']
# ['x64/Release/data/img/pa_0_1137.jpg']
# ['x64/Release/data/img/pa_0_1138.jpg']
# ['x64/Release/data/img/pa_0_1146.jpg']
# ['x64/Release/data/img/pa_0_1147.jpg']
# ['x64/Release/data/img/pa_0_1183.jpg']
# ['x64/Release/data/img/pa_0_1184.jpg']
# ['x64/Release/data/img/pa_0_1192.jpg']
# ['x64/Release/data/img/pa_0_1204.jpg']
# ['x64/Release/data/img/pa_0_1228.jpg']
# ['x64/Release/data/img/pa_0_1233.jpg']
# ...

# %%
datafr = pd.DataFrame(a)
datafr.head()
# Out:
#                                         0
# 0  ['x64/Release/data/img/pa_0_1003.jpg']
# 1  ['x64/Release/data/img/pa_0_1013.jpg']
# 2  ['x64/Release/data/img/pa_0_1017.jpg']
# 3   ['x64/Release/data/img/pa_0_102.jpg']
# 4  ['x64/Release/data/img/pa_0_1028.jpg']

# %%
f_path = '/content/file.txt'
with open(f_path, 'w') as output:
  for row in a:
    output.write(str(row)+'\n')

# %% [markdown]
# * list append(X) / DataFrame append

# %%
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-115-901033615de5>", line 5, in <module>
#     dfa.append(change)
#   File "/usr/local/lib/python3.7/dist-packages/pandas/core/frame.py", line 7751, in append
#     sort=sort,
#   File "/usr/local/lib/python3.7/dist-packages/pandas/core/reshape/concat.py", line 284, in concat
#     sort=sort,
#   File "/usr/local/lib/python3.7/dist-packages/pandas/core/reshape/concat.py", line 359, in __init__
#     raise TypeError(msg)
# TypeError: cannot concatenate object of type '<class 'str'>'; only Series and DataFrame objs are valid
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
# ...

# %%
txt_name = '/content/file.txt'
df =pd.read_csv(txt_name)
df.head()
# Out:
#    ['x64/Release/data/img/pa_0_1003.jpg']
# 0  ['x64/Release/data/img/pa_0_1013.jpg']
# 1  ['x64/Release/data/img/pa_0_1017.jpg']
# 2   ['x64/Release/data/img/pa_0_102.jpg']
# 3  ['x64/Release/data/img/pa_0_1028.jpg']
# 4  ['x64/Release/data/img/pa_0_1033.jpg']

# %%
# %cd /content/drive
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-142-ed3eb793ab11>", line 1, in <module>
#     get_ipython().magic('cd /content/drive')
#   File "/usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py", line 2160, in magic
#     return self.run_line_magic(magic_name, magic_arg_s)
#   File "/usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py", line 2081, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-84>", line 2, in cd
#   File "/usr/local/lib/python3.7/dist-packages/IPython/core/magic.py", line 188, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
# ...

# %%
f_path = '/content/file.txt'

f = open(f_path, 'w')
for line in f:

  line.replace('[','')

f.close()
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-135-47271cebdbb7>", line 4, in <module>
#     for line in f:
# io.UnsupportedOperation: not readable
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py", line 1823, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'UnsupportedOperation' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/IPython/core/ultratb.py", line 1132, in get_records
# ...

# %%
open_file = open(f_path,'r')
read_file = open_file.read()

# %%
import re

regex = re.compile('[')
read_file = regex.sub('', read_file)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-137-7dff30351b33>", line 3, in <module>
#     regex = re.compile('[')
#   File "/usr/lib/python3.7/re.py", line 236, in compile
#     return _compile(pattern, flags)
#   File "/usr/lib/python3.7/re.py", line 288, in _compile
#     p = sre_compile.compile(pattern, flags)
#   File "/usr/lib/python3.7/sre_compile.py", line 764, in compile
#     p = sre_parse.parse(p, flags)
#   File "/usr/lib/python3.7/sre_parse.py", line 924, in parse
#     p = _parse_sub(source, pattern, flags & SRE_FLAG_VERBOSE, 0)
#   File "/usr/lib/python3.7/sre_parse.py", line 420, in _parse_sub
#     not nested and not items))
# ...

# %%
848*0.7
# Out:
# 593.5999999999999
