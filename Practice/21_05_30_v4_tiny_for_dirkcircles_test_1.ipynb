# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !tar -xzvf /content/drive/My\ Drive/Colab\ Notebooks/datasets/darknet/cudnn/cudnn-11.3-linux-x64-v8.2.0.53.solitairetheme8 -C /usr/local/
# Out:
# cuda/include/cudnn.h
# cuda/include/cudnn_adv_infer.h
# cuda/include/cudnn_adv_infer_v8.h
# cuda/include/cudnn_adv_train.h
# cuda/include/cudnn_adv_train_v8.h
# cuda/include/cudnn_backend.h
# cuda/include/cudnn_backend_v8.h
# cuda/include/cudnn_cnn_infer.h
# cuda/include/cudnn_cnn_infer_v8.h
# cuda/include/cudnn_cnn_train.h
# cuda/include/cudnn_cnn_train_v8.h
# cuda/include/cudnn_ops_infer.h
# cuda/include/cudnn_ops_infer_v8.h
# cuda/include/cudnn_ops_train.h
# cuda/include/cudnn_ops_train_v8.h
# cuda/include/cudnn_v8.h
# cuda/include/cudnn_version.h
# cuda/include/cudnn_version_v8.h
# cuda/NVIDIA_SLA_cuDNN_Support.txt
# cuda/lib64/libcudnn.so
# cuda/lib64/libcudnn.so.8
# cuda/lib64/libcudnn.so.8.2.0
# cuda/lib64/libcudnn_adv_infer.so
# cuda/lib64/libcudnn_adv_infer.so.8
# cuda/lib64/libcudnn_adv_infer.so.8.2.0
# cuda/lib64/libcudnn_adv_train.so
# cuda/lib64/libcudnn_adv_train.so.8
# cuda/lib64/libcudnn_adv_train.so.8.2.0
# cuda/lib64/libcudnn_cnn_infer.so
# ...

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/datasets/darknet
# Out:
# /content/drive/MyDrive/Colab Notebooks/datasets/darknet

# %%
# !chmod 775 darknet

# %%
# %%time
# !./darknet detector train Project_darkcircle/obj.data cfg/yolov4-tiny.cfg project/yolov4-tiny.conv.29 -dont_show
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#  Very small path to the image:
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.746377), count: 34, class_loss = 0.120239, iou_loss = 0.339535, total_loss = 0.459774
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.836353), count: 28, class_loss = 0.072161, iou_loss = 0.352846, total_loss = 0.425007
#  total_bbox = 62592, rewritten_bbox = 0.000000 %
#
#  Tensor Cores are disabled until the first 3000 iterations are reached.
#
#  1156: 0.096428, 0.079374 avg loss, 0.002610 rate, 0.623931 seconds, 73984 images, 1313.927056 hours left
# Loaded: 1.741844 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.749182), count: 29, class_loss = 0.145663, iou_loss = 0.239700, total_loss = 0.385363
# ...

# %%
# !./darknet detector map Project_darkcircle/obj.data cfg/yolov4-tiny.cfg Project_darkcircle/backup/yolov4-tiny_last.weights
# Out:
#  CUDA-version: 11000 (11020), cuDNN: 8.2.0, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 750, cudnn_half = 1, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 2    416 x 416 x   3 ->  208 x 208 x  32 0.075 BF
#    1 conv     64       3 x 3/ 2    208 x 208 x  32 ->  104 x 104 x  64 0.399 BF
#    2 conv     64       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x  64 0.797 BF
#    3 route  2 		                       1/2 ->  104 x 104 x  32
#    4 conv     32       3 x 3/ 1    104 x 104 x  32 ->  104 x 104 x  32 0.199 BF
#    5 conv     32       3 x 3/ 1    104 x 104 x  32 ->  104 x 104 x  32 0.199 BF
#    6 route  5 4 	                           ->  104 x 104 x  64
# ...

# %%
# !./darknet detector train Project_darkcircle/obj.data cfg/yolov4-tiny.cfg Project_darkcircle/backup/yolov4-tiny_last.weights -map

# %%
def imShow(path):
  import cv2
  import matplotlib.pyplot as plt
  # %matplotlib inline

  image = cv2.imread(path)
  height, width = image.shape[:2]
  resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

  fig = plt.gcf()
  fig.set_size_inches(18, 10)
  plt.axis("off")
  plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
  plt.show()

# %%
# %%time
# !./darknet detector test Project_darkcircle/obj.data cfg/yolov4-tiny.cfg Project_darkcircle/backup/yolov4-tiny_last.weights project/darkcircle_img/test.jpg -thresh 0.2 

imShow("predictions.jpg")
# Out:
#  CUDA-version: 11000 (11020), cuDNN: 8.2.0, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 3.2.0
# Cannot load image data/labels/32_0.png
# Cannot load image data/labels/33_0.png
# Cannot load image data/labels/34_0.png
# Cannot load image data/labels/35_0.png
# Cannot load image data/labels/36_0.png
# Cannot load image data/labels/37_0.png
# Cannot load image data/labels/38_0.png
# Cannot load image data/labels/39_0.png
# Cannot load image data/labels/40_0.png
# Cannot load image data/labels/41_0.png
# Cannot load image data/labels/42_0.png
# Cannot load image data/labels/43_0.png
# Cannot load image data/labels/44_0.png
# Cannot load image data/labels/45_0.png
# Cannot load image data/labels/46_0.png
# Cannot load image data/labels/47_0.png
# Cannot load image data/labels/48_0.png
# Cannot load image data/labels/49_0.png
# Cannot load image data/labels/50_0.png
# Cannot load image data/labels/51_0.png
# Cannot load image data/labels/52_0.png
# ...

# %%
# %%time
# !./darknet detector test Project_darkcircle/obj.data cfg/yolov4-tiny.cfg Project_darkcircle/backup/yolov4-tiny_last.weights project/darkcircle_img/test10.jpg -thresh 0.2 

imShow("predictions.jpg")
# Out:
#  CUDA-version: 11000 (11020), cuDNN: 8.2.0, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 3.2.0
# Cannot load image data/labels/32_0.png
# Cannot load image data/labels/33_0.png
# Cannot load image data/labels/34_0.png
# Cannot load image data/labels/35_0.png
# Cannot load image data/labels/36_0.png
# Cannot load image data/labels/37_0.png
# Cannot load image data/labels/38_0.png
# Cannot load image data/labels/39_0.png
# Cannot load image data/labels/40_0.png
# Cannot load image data/labels/41_0.png
# Cannot load image data/labels/42_0.png
# Cannot load image data/labels/43_0.png
# Cannot load image data/labels/44_0.png
# Cannot load image data/labels/45_0.png
# Cannot load image data/labels/46_0.png
# Cannot load image data/labels/47_0.png
# Cannot load image data/labels/48_0.png
# Cannot load image data/labels/49_0.png
# Cannot load image data/labels/50_0.png
# Cannot load image data/labels/51_0.png
# Cannot load image data/labels/52_0.png
# ...

# %%
# %%time
# !./darknet detector test Project_darkcircle/obj.data cfg/yolov4-tiny.cfg Project_darkcircle/backup/yolov4-tiny_last.weights project/darkcircle_img/test11.jpg -thresh 0.2 

imShow("predictions.jpg")

# %%
# %%time
# !./darknet detector test Project_darkcircle/obj.data cfg/yolov4-tiny.cfg Project_darkcircle/backup/yolov4-tiny_last.weights project/darkcircle_img/test12.jpg -thresh 0.2 

imShow("predictions.jpg")

# %%
# %%time
# !./darknet detector test Project_darkcircle/obj.data cfg/yolov4-tiny.cfg Project_darkcircle/backup/yolov4-tiny_last.weights project/darkcircle_img/test13.jpg -thresh 0.2 

imShow("predictions.jpg")

# %%
# %%time
# !./darknet detector test Project_darkcircle/obj.data cfg/yolov4-tiny.cfg Project_darkcircle/backup/yolov4-tiny_last.weights project/darkcircle_img/test14.jpg -thresh 0.2 

imShow("predictions.jpg")

# %%
# %%time
# !./darknet detector test Project_darkcircle/obj.data cfg/yolov4-tiny.cfg Project_darkcircle/backup/yolov4-tiny_last.weights project/darkcircle_img/test2.jpg -thresh 0.2 

imShow("predictions.jpg")

# %%
# %%time
# !./darknet detector test Project_darkcircle/obj.data cfg/yolov4-tiny.cfg Project_darkcircle/backup/yolov4-tiny_last.weights project/darkcircle_img/test3.jpg -thresh 0.2 

imShow("predictions.jpg")
# Out:
#  CUDA-version: 11000 (11020), cuDNN: 8.2.0, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 3.2.0
# Cannot load image data/labels/32_0.png
# Cannot load image data/labels/33_0.png
# Cannot load image data/labels/34_0.png
# Cannot load image data/labels/35_0.png
# Cannot load image data/labels/36_0.png
# Cannot load image data/labels/37_0.png
# Cannot load image data/labels/38_0.png
# Cannot load image data/labels/39_0.png
# Cannot load image data/labels/40_0.png
# Cannot load image data/labels/41_0.png
# Cannot load image data/labels/42_0.png
# Cannot load image data/labels/43_0.png
# Cannot load image data/labels/44_0.png
# Cannot load image data/labels/45_0.png
# Cannot load image data/labels/46_0.png
# Cannot load image data/labels/47_0.png
# Cannot load image data/labels/48_0.png
# Cannot load image data/labels/49_0.png
# Cannot load image data/labels/50_0.png
# Cannot load image data/labels/51_0.png
# Cannot load image data/labels/52_0.png
# ...

# %%
# %%time
# !./darknet detector test Project_darkcircle/obj.data cfg/yolov4-tiny.cfg Project_darkcircle/backup/yolov4-tiny_last.weights project/darkcircle_img/test5.jpg -thresh 0.2 

imShow("predictions.jpg")

# %%
# %%time
# !./darknet detector test Project_darkcircle/obj.data cfg/yolov4-tiny.cfg Project_darkcircle/backup/yolov4-tiny_last.weights project/darkcircle_img/test6.jpg -thresh 0.2 

imShow("predictions.jpg")
# Out:
#  CUDA-version: 11000 (11020), cuDNN: 8.2.0, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 3.2.0
# Cannot load image data/labels/32_0.png
# Cannot load image data/labels/33_0.png
# Cannot load image data/labels/34_0.png
# Cannot load image data/labels/35_0.png
# Cannot load image data/labels/36_0.png
# Cannot load image data/labels/37_0.png
# Cannot load image data/labels/38_0.png
# Cannot load image data/labels/39_0.png
# Cannot load image data/labels/40_0.png
# Cannot load image data/labels/41_0.png
# Cannot load image data/labels/42_0.png
# Cannot load image data/labels/43_0.png
# Cannot load image data/labels/44_0.png
# Cannot load image data/labels/45_0.png
# Cannot load image data/labels/46_0.png
# Cannot load image data/labels/47_0.png
# Cannot load image data/labels/48_0.png
# Cannot load image data/labels/49_0.png
# Cannot load image data/labels/50_0.png
# Cannot load image data/labels/51_0.png
# Cannot load image data/labels/52_0.png
# ...

# %%
# %%time
# !./darknet detector test Project_darkcircle/obj.data cfg/yolov4-tiny.cfg Project_darkcircle/backup/yolov4-tiny_last.weights project/darkcircle_img/test7.jpg -thresh 0.2 

imShow("predictions.jpg")

# %%
# %%time
# !./darknet detector test Project_darkcircle/obj.data cfg/yolov4-tiny.cfg Project_darkcircle/backup/yolov4-tiny_last.weights project/darkcircle_img/test8.jpg -thresh 0.2 

imShow("predictions.jpg")

# %%
# %%time
# !./darknet detector test Project_darkcircle/obj.data cfg/yolov4-tiny.cfg Project_darkcircle/backup/yolov4-tiny_last.weights project/darkcircle_img/test9.jpg -thresh 0.2 

imShow("predictions.jpg")
# Out:
#  CUDA-version: 11000 (11020), cuDNN: 8.2.0, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 3.2.0
# Cannot load image data/labels/32_0.png
# Cannot load image data/labels/33_0.png
# Cannot load image data/labels/34_0.png
# Cannot load image data/labels/35_0.png
# Cannot load image data/labels/36_0.png
# Cannot load image data/labels/37_0.png
# Cannot load image data/labels/38_0.png
# Cannot load image data/labels/39_0.png
# Cannot load image data/labels/40_0.png
# Cannot load image data/labels/41_0.png
# Cannot load image data/labels/42_0.png
# Cannot load image data/labels/43_0.png
# Cannot load image data/labels/44_0.png
# Cannot load image data/labels/45_0.png
# Cannot load image data/labels/46_0.png
# Cannot load image data/labels/47_0.png
# Cannot load image data/labels/48_0.png
# Cannot load image data/labels/49_0.png
# Cannot load image data/labels/50_0.png
# Cannot load image data/labels/51_0.png
# Cannot load image data/labels/52_0.png
# ...
