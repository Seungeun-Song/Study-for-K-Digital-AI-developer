# %%
print('Hello World')

# %%
print("Hello World", end = "\t")

# %%
print("Hello", "World", sep="-")

# %%
koo = 'Data Analytics'

# %%
print(koo)

# %%
type(koo)

# %%
help(print)

# %%
# 10진수
type(888)
# Out:
# int

# %%
# 8진수
type(0o77)
# Out:
# int

# %%
# 16진수
type(0xff)
# Out:
# int

# %%
# 2진수
type(0b1001)
# Out:
# int

# %%
type(3.14)

# %%
type(5e-9)

# %%
type(5e+8)

# %%
type(8+9j)
# Out:
# complex

# %%
type('A')
# Out:
# str

# %%
type(8.)
# Out:
# float

# %%
type('Data Analytics')

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %%
8+9
# Out:
# 17

# %%
# 여기서 +는 concatenate
'a'+'b'
# Out:
# 'ab'

# %%
'a' * 3
# Out:
# 'aaa'

# %%
8-9

# %%
8*9

# %%
10/3

# %%
10//3

# %%
10%3

# %%
9 ** 2
# Out:
# 81

# %%
# 제곱 (= 9 ** 2)

pow(9, 2)
# Out:
# 81

# %%
# 절댓값

abs(-3)

# %% [markdown]
# # 진법 변환

# %%
hex(16)

# %%
# 8진법(octal)

oct(8)

# %%
bin(9)

# %%
round(24.47)
# Out:
# 24

# %%
round(24.57)
# Out:
# 25

# %%
round(24.57, ndigits = 0
# Out:
#   File "<ipython-input-152-7ef999867f8d>", line 1
#     round(24.57, ndigits = 0
#                             ^
# SyntaxError: unexpected EOF while parsing

# %%
round(24.57, ndigits=1)
# Out:
# 24.6

# %%
round(25.47, ndigits= -1)
# Out:
# 30.0

# %%
round(25.478, ndigits = 2)
# Out:
# 25.48

# %%
import math

# %%
math.pi

# %%
math.e

# %%
# 올림
math.ceil(24.99)
# Out:
# 25

# %%
# 내림
math.floor(24.99)
# Out:
# 24

# %%
# 버림
math.trunc(24.99)
# Out:
# 24

# %%
math.log(100, 10)
# Out:
# 2.0

# %%
math.log10(100)
# Out:
# 2.0

# %%
math.log(100,2)
# Out:
# 6.643856189774725

# %%
math.log2(100)
# Out:
# 6.643856189774724

# %%
# 오일러 상수를 밑으로 하는 100  -> loge(100)
math.log(100)
# Out:
# 4.605170185988092

# %%
# square root
math.sqrt(81)
# Out:
# 9.0

# %%
math.sin(45)

# %%
math.cos(45)

# %%
math.tan(45)

# %%
koo = 88
print(koo)

# %%
koo += 11
print(koo)

# %%
koo -= 11
print(koo)

# %%
koo *= 10
print(koo)

# %%
koo /= 10
print(koo)

# %%
koo //= 10
print(koo)

# %%
koo %= 3
print(koo)

# %%
koo **= 2
print(koo)

# %%
8>9

# %%
8<9

# %%
8>=9

# %%
8<=9

# %%
8 == 9

# %%
8 != 9

# %%
'A' > 'B'

# %%
'A' < 'B'

# %%
'A' == 'B'

# %%
'A' != 'B'

# %%
'팔'>9

# %%
'A' > 9

# %%
X = True
Y = False
Z = True

print(X, Y, Z)

# %%
X and Y

# %%
X or Y

# %%
not X

# %%
(X and Y) and (Y or Z)

# %%
n = 8
m = 9

# %%
n is m

# %%
n is not m

# %%
'o' in 'koo'

# %%
'J' not in 'koo'
