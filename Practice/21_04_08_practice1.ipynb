# %%
import keras 
import numpy as np

# %%
import tensorflow_hub as hub

url = "https://tfhub.dev/google/tf2-preview/mobilenet_v2/classification/2"

MbNetV2 = keras.Sequential([hub.KerasLayer(handle=url, input_shape=(224,224,3), trainable=False)])
MbNetV2.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# keras_layer (KerasLayer)     (None, 1001)              3540265
# =================================================================
# Total params: 3,540,265
# Trainable params: 0
# Non-trainable params: 3,540,265
# _________________________________________________________________

# %%
# %%time

import os

image_url = 'https://s3-us-west-2.amazonaws.com/imagenetv2public/imagenetv2-top-images.tar.gz'
data_dir = '/content/'

datat_root_orig = keras.utils.get_file('imagenetV2', image_url, cache_dir=data_dir, extract=True)
# Out:
# Downloading data from https://s3-us-west-2.amazonaws.com/imagenetv2public/imagenetv2-top-images.tar.gz
# 1245929472/1245927936 [==============================] - 34s 0us/step
# CPU times: user 6.74 s, sys: 4.52 s, total: 11.3 s
# Wall time: 39.4 s

# %%
import pathlib
from glob import glob

data_root = pathlib.Path(glob('/content/datasets/*/')[0])
print(data_root)
# Out:
# /content/datasets/imagenetv2-top-images-format-val

# %%
# !ls /content/datasets/imagenetv2-top-images-format-val/
# Out:
# 0    155  211  269  325  382  439  496	552  609  666  722  78	 836  893  95
# 1    156  212  27   326  383  44   497	553  61   667  723  780  837  894  950
# 10   157  213  270  327  384  440  498	554  610  668  724  781  838  895  951
# 100  158  214  271  328  385  441  499	555  611  669  725  782  839  896  952
# 101  159  215  272  329  386  442  5	556  612  67   726  783  84   897  953
# 102  16   216  273  33	 387  443  50	557  613  670  727  784  840  898  954
# 103  160  217  274  330  388  444  500	558  614  671  728  785  841  899  955
# 104  161  218  275  331  389  445  501	559  615  672  729  786  842  9    956
# 105  162  219  276  332  39   446  502	56   616  673  73   787  843  90   957
# 106  163  22   277  333  390  447  503	560  617  674  730  788  844  900  958
# 107  164  220  278  334  391  448  504	561  618  675  731  789  845  901  959
# 108  165  221  279  335  392  449  505	562  619  676  732  79	 846  902  96
# 109  166  222  28   336  393  45   506	563  62   677  733  790  847  903  960
# 11   167  223  280  337  394  450  507	564  620  678  734  791  848  904  961
# 110  168  224  281  338  395  451  508	565  621  679  735  792  849  905  962
# 111  169  225  282  339  396  452  509	566  622  68   736  793  85   906  963
# 112  17   226  283  34	 397  453  51	567  623  680  737  794  850  907  964
# 113  170  227  284  340  398  454  510	568  624  681  738  795  851  908  965
# 114  171  228  285  341  399  455  511	569  625  682  739  796  852  909  966
# 115  172  229  286  342  4    456  512	57   626  683  74   797  853  91   967
# 116  173  23   287  343  40   457  513	570  627  684  740  798  854  910  968
# 117  174  230  288  344  400  458  514	571  628  685  741  799  855  911  969
# 118  175  231  289  345  401  459  515	572  629  686  742  8	 856  912  97
# 119  176  232  29   346  402  46   516	573  63   687  743  80	 857  913  970
# 12   177  233  290  347  403  460  517	574  630  688  744  800  858  914  971
# 120  178  234  291  348  404  461  518	575  631  689  745  801  859  915  972
# 121  179  235  292  349  405  462  519	576  632  69   746  802  86   916  973
# 122  18   236  293  35	 406  463  52	577  633  690  747  803  860  917  974
# 123  180  237  294  350  407  464  520	578  634  691  748  804  861  918  975
# 124  181  238  295  351  408  465  521	579  635  692  749  805  862  919  976
# 125  182  239  296  352  409  466  522	58   636  693  75   806  863  92   977
# 126  183  24   297  353  41   467  523	580  637  694  750  807  864  920  978
# 127  184  240  298  354  410  468  524	581  638  695  751  808  865  921  979
# 128  185  241  299  355  411  469  525	582  639  696  752  809  866  922  98
# 129  186  242  3    356  412  47   526	583  64   697  753  81	 867  923  980
# 13   187  243  30   357  413  470  527	584  640  698  754  810  868  924  981
# 130  188  244  300  358  414  471  528	585  641  699  755  811  869  925  982
# 131  189  245  301  359  415  472  529	586  642  7    756  812  87   926  983
# 132  19   246  302  36	 416  473  53	587  643  70   757  813  870  927  984
# 133  190  247  303  360  417  474  530	588  644  700  758  814  871  928  985
# 134  191  248  304  361  418  475  531	589  645  701  759  815  872  929  986
# 135  192  249  305  362  419  476  532	59   646  702  76   816  873  93   987
# 136  193  25   306  363  42   477  533	590  647  703  760  817  874  930  988
# 137  194  250  307  364  420  478  534	591  648  704  761  818  875  931  989
# 138  195  251  308  365  421  479  535	592  649  705  762  819  876  932  99
# 139  196  252  309  366  422  48   536	593  65   706  763  82	 877  933  990
# 14   197  253  31   367  423  480  537	594  650  707  764  820  878  934  991
# 140  198  254  310  368  424  481  538	595  651  708  765  821  879  935  992
# 141  199  255  311  369  425  482  539	596  652  709  766  822  88   936  993
# 142  2	  256  312  37	 426  483  54	597  653  71   767  823  880  937  994
# 143  20   257  313  370  427  484  540	598  654  710  768  824  881  938  995
# 144  200  258  314  371  428  485  541	599  655  711  769  825  882  939  996
# 145  201  259  315  372  429  486  542	6    656  712  77   826  883  94   997
# 146  202  26   316  373  43   487  543	60   657  713  770  827  884  940  998
# 147  203  260  317  374  430  488  544	600  658  714  771  828  885  941  999
# 148  204  261  318  375  431  489  545	601  659  715  772  829  886  942
# 149  205  262  319  376  432  49   546	602  66   716  773  83	 887  943
# 15   206  263  32   377  433  490  547	603  660  717  774  830  888  944
# 150  207  264  320  378  434  491  548	604  661  718  775  831  889  945
# 151  208  265  321  379  435  492  549	605  662  719  776  832  89   946
# 152  209  266  322  38	 436  493  55	606  663  72   777  833  890  947
# 153  21   267  323  380  437  494  550	607  664  720  778  834  891  948
# 154  210  268  324  381  438  495  551	608  665  721  779  835  892  949

# %%
import pandas as pd

url = 'https://storage.googleapis.com/download.tensorflow.org/data/ImageNetLabels.txt'
DF = pd.read_table(url, header=None)

label_text = DF.values.reshape(-1)
print(DF.info())
print(label_test)
print(len(label_test))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       1001 non-null   object
# dtypes: object(1)
# memory usage: 7.9+ KB
# None
# ['background' 'tench' 'goldfish' ... 'bolete' 'ear' 'toilet tissue']
# 1001

# %%
DF.head()
# Out:
#                    0
# 0         background
# 1              tench
# 2           goldfish
# 3  great white shark
# 4        tiger shark

# %%
import random

all_image_paths = list(data_root.glob('*/*'))
print(all_image_paths)
all_image_paths = [str(path) for path in all_image_paths]
print(all_image_paths)

random.choice(all_image_paths)
# Out:
# [PosixPath('/content/datasets/imagenetv2-top-images-format-val/72/13ab4e39e217d3ef5da1b51a902e6720175ac64d.jpeg'), PosixPath('/content/datasets/imagenetv2-top-images-format-val/72/e35a4c1d7aa849086fe1d8d80f50890b329e19de.jpeg'), PosixPath('/content/datasets/imagenetv2-top-images-format-val/72/ae70b76eadc1276522f2befe6e09802740bfd7d2.jpeg'), PosixPath('/content/datasets/imagenetv2-top-images-format-val/72/ed165acbe2d5802d6cf1da5b916bec30622824cd.jpeg'), PosixPath('/content/datasets/imagenetv2-top-images-format-val/72/582ac474e689252acde9530890857337b1fb0b74.jpeg'), PosixPath('/content/datasets/imagenetv2-top-images-format-val/72/fd11247f99ec2d7eebca5da3d5d0039ee3716856.jpeg'), PosixPath('/content/datasets/imagenetv2-top-images-format-val/72/a9bf36516a96f649c3a1239aabb0236df208fbd1.jpeg'), PosixPath('/content/datasets/imagenetv2-top-images-format-val/72/4b8b6ace95bd8e5b57c37b1ad21cb2666d3ea200.jpeg'), PosixPath('/content/datasets/imagenetv2-top-images-format-val/72/da1134239c4323070a34c81dd6ab57fadaea24b9.jpeg'), PosixPath('/content/datasets/imagenetv2-top-images-format-val/72/ad6cec1a38d111918eabfd23a2289c5401566785.jpeg'), PosixPath('/content/datasets/imagenetv2-top-images-format-val/401/47a86f7cbf5be435a9dee3c830bf8e280ea458cb.jpeg'), PosixPath('/content/datasets/imagenetv2-top-images-format-val/401/2d8edb636013651c803bc8062c4d053f36b8a6cd.jpeg'), PosixPath('/content/datasets/imagenetv2-top-images-format-val/401/b43ee22b6bfbad8e396f0f789f2cbd1f9f66f3ab.jpeg'), PosixPath('/content/datasets/imagenetv2-top-images-format-val/401/7b4385f37e79c4722f404399aac3f963b9a78ff2.jpeg'), PosixPath('/content/datasets/imagenetv2-top-images-format-val/401/e8a09f74728e8517a13fdb54480475076238a204.jpeg'), PosixPath('/content/datasets/imagenetv2-top-images-format-val/401/6bac75163f0f3da4b231ce3f53f003aed139dfe6.jpeg'), PosixPath('/content/datasets/imagenetv2-top-images-format-val/401/be4881e28441c8cef5a1f4749812b330419fc4ac.jpeg'), PosixPath('/content/datasets/imagenetv2-top-images-format-val/401/bb70cdda7cbaf3ba7ac3addb48df28fb0e3c3eb1.jpeg'), PosixPath('/content/datasets/imagenetv2-top-images-format-val/401/700b9a77765d63d9898916cec39ec91fb71551dc.jpeg'), PosixPath('/content/datasets/imagenetv2-top-images-format-val/401/2f22460395095964c87987de1deb0d2bf69d6442.jpeg'), PosixPath('/content/datasets/imagenetv2-top-images-format-val/820/faa18786f7d0bc751c35e91757435d20593ee1b3.jpeg'), PosixPath('/content/datasets/imagenetv2-top-images-format-val/820/b72f56797bc69c0cadd6cfc0b47143bce3283513.jpeg'), PosixPath('/content/datasets/imagenetv2-top-images-format-val/820/639748841358f8bf21dd4f139065abfd95f6d1b2.jpeg'), PosixPath('/content/datasets/imagenetv2-top-images-format-val/820/fab3f632c2521cd6957ea506a2bcfd43a94549f4.jpeg'), PosixPath('/content/datasets/imagenetv2-top-images-format-val/820/ca78db9446eec86397c9958acd64aa383bfef2ed.jpeg'), PosixPath('/content/datasets/imagenetv2-top-images-format-val/820/74f5fac77926b4fd3940a33a5ff7952a2e09cde7.jpeg'), PosixPath('/content/datasets/imagenetv2-top-images-format-val/820/a0d0f66f29af7dccb9ccd85b02ca10608ae485a1.jpeg'), PosixPath('/content/datasets/imagenetv2-top-images-format-val/820/bd7b69def3fba22bc0f316490237581ac014e86f.jpeg'), PosixPath('/content/datasets/imagenetv2-top-images-format-val/820/d3a837cd5ed7205474262e12a8f8c1f82831c5d5.jpeg'), PosixPath('/content/datasets/imagenetv2-top-images-format-val/820/6c99b6a96dcd74b8eeaeee1d59ff998e971b0f9d.jpeg'), PosixPath('/content/datasets/imagenetv2-top-images-format-val/484/ae4da505459cd7aeccab0cc046c1626ec161d24a.jpeg'), PosixPath('/content/datasets/imagenetv2-top-images-format-val/484/1fd702d2cd0803d18bc251fdefe82e310d6c7974.jpeg'), PosixPath('/content/datasets/imagenetv2-top-images-format-val/484/573704bd8a9c70a3a495862f9bd11d862334f84b.jpeg'), PosixPath('/content/datasets/imagenetv2-top-images-format-val/484/ba065927c807aa68e053ed097c1e4f514ea87fee.jpeg'), PosixPath('/content/datasets/imagenetv2-top-images-format-val/484/4a203b8983cca7a8c48937274c997a1d9 ...
# ['/content/datasets/imagenetv2-top-images-format-val/72/13ab4e39e217d3ef5da1b51a902e6720175ac64d.jpeg', '/content/datasets/imagenetv2-top-images-format-val/72/e35a4c1d7aa849086fe1d8d80f50890b329e19de.jpeg', '/content/datasets/imagenetv2-top-images-format-val/72/ae70b76eadc1276522f2befe6e09802740bfd7d2.jpeg', '/content/datasets/imagenetv2-top-images-format-val/72/ed165acbe2d5802d6cf1da5b916bec30622824cd.jpeg', '/content/datasets/imagenetv2-top-images-format-val/72/582ac474e689252acde9530890857337b1fb0b74.jpeg', '/content/datasets/imagenetv2-top-images-format-val/72/fd11247f99ec2d7eebca5da3d5d0039ee3716856.jpeg', '/content/datasets/imagenetv2-top-images-format-val/72/a9bf36516a96f649c3a1239aabb0236df208fbd1.jpeg', '/content/datasets/imagenetv2-top-images-format-val/72/4b8b6ace95bd8e5b57c37b1ad21cb2666d3ea200.jpeg', '/content/datasets/imagenetv2-top-images-format-val/72/da1134239c4323070a34c81dd6ab57fadaea24b9.jpeg', '/content/datasets/imagenetv2-top-images-format-val/72/ad6cec1a38d111918eabfd23a2289c5401566785.jpeg', '/content/datasets/imagenetv2-top-images-format-val/401/47a86f7cbf5be435a9dee3c830bf8e280ea458cb.jpeg', '/content/datasets/imagenetv2-top-images-format-val/401/2d8edb636013651c803bc8062c4d053f36b8a6cd.jpeg', '/content/datasets/imagenetv2-top-images-format-val/401/b43ee22b6bfbad8e396f0f789f2cbd1f9f66f3ab.jpeg', '/content/datasets/imagenetv2-top-images-format-val/401/7b4385f37e79c4722f404399aac3f963b9a78ff2.jpeg', '/content/datasets/imagenetv2-top-images-format-val/401/e8a09f74728e8517a13fdb54480475076238a204.jpeg', '/content/datasets/imagenetv2-top-images-format-val/401/6bac75163f0f3da4b231ce3f53f003aed139dfe6.jpeg', '/content/datasets/imagenetv2-top-images-format-val/401/be4881e28441c8cef5a1f4749812b330419fc4ac.jpeg', '/content/datasets/imagenetv2-top-images-format-val/401/bb70cdda7cbaf3ba7ac3addb48df28fb0e3c3eb1.jpeg', '/content/datasets/imagenetv2-top-images-format-val/401/700b9a77765d63d9898916cec39ec91fb71551dc.jpeg', '/content/datasets/imagenetv2-top-images-format-val/401/2f22460395095964c87987de1deb0d2bf69d6442.jpeg', '/content/datasets/imagenetv2-top-images-format-val/820/faa18786f7d0bc751c35e91757435d20593ee1b3.jpeg', '/content/datasets/imagenetv2-top-images-format-val/820/b72f56797bc69c0cadd6cfc0b47143bce3283513.jpeg', '/content/datasets/imagenetv2-top-images-format-val/820/639748841358f8bf21dd4f139065abfd95f6d1b2.jpeg', '/content/datasets/imagenetv2-top-images-format-val/820/fab3f632c2521cd6957ea506a2bcfd43a94549f4.jpeg', '/content/datasets/imagenetv2-top-images-format-val/820/ca78db9446eec86397c9958acd64aa383bfef2ed.jpeg', '/content/datasets/imagenetv2-top-images-format-val/820/74f5fac77926b4fd3940a33a5ff7952a2e09cde7.jpeg', '/content/datasets/imagenetv2-top-images-format-val/820/a0d0f66f29af7dccb9ccd85b02ca10608ae485a1.jpeg', '/content/datasets/imagenetv2-top-images-format-val/820/bd7b69def3fba22bc0f316490237581ac014e86f.jpeg', '/content/datasets/imagenetv2-top-images-format-val/820/d3a837cd5ed7205474262e12a8f8c1f82831c5d5.jpeg', '/content/datasets/imagenetv2-top-images-format-val/820/6c99b6a96dcd74b8eeaeee1d59ff998e971b0f9d.jpeg', '/content/datasets/imagenetv2-top-images-format-val/484/ae4da505459cd7aeccab0cc046c1626ec161d24a.jpeg', '/content/datasets/imagenetv2-top-images-format-val/484/1fd702d2cd0803d18bc251fdefe82e310d6c7974.jpeg', '/content/datasets/imagenetv2-top-images-format-val/484/573704bd8a9c70a3a495862f9bd11d862334f84b.jpeg', '/content/datasets/imagenetv2-top-images-format-val/484/ba065927c807aa68e053ed097c1e4f514ea87fee.jpeg', '/content/datasets/imagenetv2-top-images-format-val/484/4a203b8983cca7a8c48937274c997a1d9761893b.jpeg', '/content/datasets/imagenetv2-top-images-format-val/484/b13d2ebee139c1d204653fd620fb0a12ca762016.jpeg', '/content/datasets/imagenetv2-top-images-format-val/484/e33f1977526f031b862f9f7696b85f65cf1c9a8f.jpeg', '/content/datasets/imagenetv2-top-images-format-val/484/e6484cace53bed78d889ccde29c012d0085613af.jpeg', '/content/datasets/imagenetv2-top-images-format-val/484/1 ...
# '/content/datasets/imagenetv2-top-images-format-val/565/0364051e9e8d50304a0c504c53c35d1b48c74ed7.jpeg'

# %%
import PIL.Image as Image  #pillow -> 이미지처리
import matplotlib.pyplot as plt

random.shuffle(all_image_paths)

image_count = len(all_image_paths)
print('image_count:', image_count)

plt.figure(figsize=(12,12))

for n in range(9):
  image_path = random.choice(all_image_paths)
  plt.subplot(3,3, n+1)
  plt.imshow(plt.imread(image_path))
  idx = int(image_path.split('/')[-2])+1
  plt.title(str(idx) + ':' + label_text[idx])
  plt.axis('off')
plt.show()
# Out:
# image_count: 10000

# %%
import cv2
plt.figure(figsize=(16,16))

def softmax(x):
  m = np.max(x)
  sm = np.exp(x-m)/np.sum(np.exp(x-m))
  return sm

for n in range(3):
  image_path = random.choice(all_image_paths)

  plt.subplot(3,2, n*2+1)
  plt.imshow(plt.imread(image_path))
  idx = int(image_path.split('/')[-2])+1
  print('1===', int(image_path.split('/')[-2]), '||||', idx)
  plt.axis('off')

  plt.subplot(3,2,n*2+2)
  img = cv2.imread(image_path)
  img = cv2.resize(img, dsize=(224,224))
  img = img/255.0
  img = np.expand_dims(img, axis=0)

  logits = MbNetV2.predict(img)[0]
  print('2===', MbNetV2.predict(img), ':::::', logits)
  prediction = softmax(logits)
  print('3===', prediction)

  top_5_predict = prediction.argsort()[::-1][:5]
  print('4===',top_5_predict)
  labels = [label_text[index] for index in top_5_predict]

  color = ['gray'] * 5
  if idx in top_5_predict:
    color[top_5_predict.tolist().index(idx)] = 'green'  # tolist = 같은 레벨(위치)에 있는 데이터끼리 묶어준다
  color = color[::-1]

  plt.barh(range(5), prediction[top_5_predict][::-1]*100, color = color)
  plt.yticks(range(5), labels[::-1])
# Out:
# 1=== 872 |||| 873
# 2=== [[ 0.30116853 -0.9629021  -0.421138   ... -1.5216738  -1.585225
#    0.55910397]] ::::: [ 0.30116853 -0.9629021  -0.421138   ... -1.5216738  -1.585225
#   0.55910397]
# 3=== [2.4137544e-04 6.8188987e-05 1.1721940e-04 ... 3.8998023e-05 3.6596772e-05
#  3.1240148e-04]
# 4=== [873 448 819 746 633]
# 1=== 970 |||| 971
# 2=== [[ 0.01896769 -0.6474524   0.03940253 ... -0.53196067  0.44294226
#    1.4961373 ]] ::::: [ 0.01896769 -0.6474524   0.03940253 ... -0.53196067  0.44294226
#   1.4961373 ]
# 3=== [0.00019969 0.00010255 0.00020381 ... 0.0001151  0.00030513 0.00087474]
# 4=== [971 981 975 980 461]
# 1=== 276 |||| 277
# 2=== [[ 0.3083134   0.00174786  1.2383221  ...  0.4788233  -1.3186564
#    0.6447028 ]] ::::: [ 0.3083134   0.00174786  1.2383221  ...  0.4788233  -1.3186564
#   0.6447028 ]
# 3=== [7.63223798e-05 5.61710185e-05 1.93441490e-04 ... 9.05114648e-05
#  1.49991865e-05 1.06842497e-04]
# 4=== [277 276 269 247 342]
