# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
MV = pd.read_csv('https://raw.githubusercontent.com/rusita-ai/pyData/master/Model_Validation.csv')

MV.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Inputs   1000 non-null   float64
#  1   Outputs  1000 non-null   float64
# dtypes: float64(2)
# memory usage: 15.8 KB

# %%
MV.head()
# Out:
#      Inputs   Outputs
# 0 -0.752759 -0.352622
# 1  2.704286  0.192409
# 2  1.391964  0.558147
# 3  0.591951  0.950694
# 4 -2.063888 -1.212273

# %%
sns.scatterplot(MV.Inputs, MV.Outputs)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.regplot(x='Inputs', y='Outputs', data=MV, 
            line_kws = {'color':'red'},
            scatter_kws={'edgecolor':'white'}) 
plt.show()

# %%
sns.regplot(x='Inputs', y='Outputs', data=MV,
            line_kws = {'color':'blue'},
            scatter_kws={'edgecolor':'white'},
            order = 5)
plt.show()

# %%
sns.regplot(x='Inputs', y='Outputs', data=MV,
            line_kws = {'color':'blue'},
            scatter_kws={'edgecolor':'white'},
            order = 7)
plt.show()

# %%
sns.regplot(x='Inputs', y='Outputs', data=MV,
            line_kws = {'color':'blue'},
            scatter_kws={'edgecolor':'white'},
            order = 9)
plt.show()

# %%
sns.regplot(x='Inputs', y='Outputs', data=MV,
            line_kws = {'color':'blue'},
            scatter_kws={'edgecolor':'white'},
            order =11)
plt.show()

# %%
sns.regplot(x='Inputs', y='Outputs', data=MV,
            line_kws = {'color':'blue'},
            scatter_kws={'edgecolor':'white'},
            order = 13)
plt.show()

# %%
sns.regplot(x='Inputs', y='Outputs', data=MV,
            line_kws = {'color':'blue'},
            scatter_kws={'edgecolor':'white'},
            order = 15)
plt.show()

# %%
sns.regplot(x='Inputs', y='Outputs', data=MV,
            line_kws = {'color':'blue'},
            scatter_kws={'edgecolor':'white'},
            order = 100)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/regression.py:256: RankWarning: Polyfit may be poorly conditioned
#   yhat = reg_func(x, y)
# /usr/local/lib/python3.7/dist-packages/seaborn/algorithms.py:85: RankWarning: Polyfit may be poorly conditioned
#   boot_dist.append(f(*sample, **func_kwargs))
# /usr/local/lib/python3.7/dist-packages/seaborn/algorithms.py:85: RankWarning: Polyfit may be poorly conditioned
#   boot_dist.append(f(*sample, **func_kwargs))
# /usr/local/lib/python3.7/dist-packages/seaborn/algorithms.py:85: RankWarning: Polyfit may be poorly conditioned
#   boot_dist.append(f(*sample, **func_kwargs))
# /usr/local/lib/python3.7/dist-packages/seaborn/algorithms.py:85: RankWarning: Polyfit may be poorly conditioned
#   boot_dist.append(f(*sample, **func_kwargs))
# /usr/local/lib/python3.7/dist-packages/seaborn/algorithms.py:85: RankWarning: Polyfit may be poorly conditioned
#   boot_dist.append(f(*sample, **func_kwargs))
# ...

# %%
sns.regplot(x='Inputs', y='Outputs', data=MV,
            line_kws = {'color':'blue'},
            scatter_kws={'edgecolor':'white'},
            order = 50)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/regression.py:256: RankWarning: Polyfit may be poorly conditioned
#   yhat = reg_func(x, y)
# /usr/local/lib/python3.7/dist-packages/seaborn/algorithms.py:85: RankWarning: Polyfit may be poorly conditioned
#   boot_dist.append(f(*sample, **func_kwargs))
# /usr/local/lib/python3.7/dist-packages/seaborn/algorithms.py:85: RankWarning: Polyfit may be poorly conditioned
#   boot_dist.append(f(*sample, **func_kwargs))
# /usr/local/lib/python3.7/dist-packages/seaborn/algorithms.py:85: RankWarning: Polyfit may be poorly conditioned
#   boot_dist.append(f(*sample, **func_kwargs))
# /usr/local/lib/python3.7/dist-packages/seaborn/algorithms.py:85: RankWarning: Polyfit may be poorly conditioned
#   boot_dist.append(f(*sample, **func_kwargs))
# /usr/local/lib/python3.7/dist-packages/seaborn/algorithms.py:85: RankWarning: Polyfit may be poorly conditioned
#   boot_dist.append(f(*sample, **func_kwargs))
# ...

# %%
sns.regplot(x='Inputs', y='Outputs', data=MV,
            line_kws = {'color':'blue'},
            scatter_kws={'edgecolor':'white'},
            order = 30)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(MV[['Inputs']], MV['Outputs'],
                                                    test_size= 0.2, random_state=2045)

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((800, 1), (800,), (200, 1), (200,))

# %%
TR_MV, TE_MV = train_test_split(MV, test_size=0.3, random_state =2045)

TR_MV.shape, TE_MV.shape
# Out:
# ((700, 2), (300, 2))

# %%
sns.scatterplot(TR_MV['Inputs'],TR_MV['Outputs'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.scatterplot(TE_MV['Inputs'],TE_MV['Outputs'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
from sklearn.preprocessing import PolynomialFeatures

poly=PolynomialFeatures(degree=5, include_bias=False)
PX_5_TR = poly.fit_transform(X_train)

# %%
from sklearn.linear_model import LinearRegression
Model_5 = LinearRegression()
Model_5.fit(PX_5_TR , y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
PX_5_TE=poly.fit_transform(X_test)
y_hat_5 = Model_5.predict(PX_5_TE)

# %%
from sklearn.metrics import mean_squared_error

TE_Err_5 = mean_squared_error(y_test, y_hat_5)
TE_Err_5
# Out:
# 0.36825787122456405

# %%
from sklearn.preprocessing import PolynomialFeatures

poly=PolynomialFeatures(degree=7, include_bias=False)
PX_7_TR = poly.fit_transform(X_train)

from sklearn.linear_model import LinearRegression
Model_7 = LinearRegression()
Model_7.fit(PX_7_TR, y_train)

PX_7_TE  = poly.fit_transform(X_test)
y_hat_7 = Model_7.predict(PX_7_TE)

from sklearn.metrics import mean_squared_error

TE_Err_7 = mean_squared_error(y_test, y_hat_7)
TE_Err_7
# Out:
# 0.36564832066023234

# %%
from sklearn.preprocessing import PolynomialFeatures

poly=PolynomialFeatures(degree=9, include_bias=False)
PX_9_TR = poly.fit_transform(X_train)

from sklearn.linear_model import LinearRegression
Model_9 = LinearRegression()
Model_9.fit(PX_9_TR, y_train)

PX_9_TE  = poly.fit_transform(X_test)
y_hat_9 = Model_9.predict(PX_9_TE)

from sklearn.metrics import mean_squared_error

TE_Err_9 = mean_squared_error(y_test, y_hat_9)
TE_Err_9
# Out:
# 0.2930399047903214

# %%
from sklearn.preprocessing import PolynomialFeatures

poly=PolynomialFeatures(degree=11, include_bias=False)
PX_11_TR = poly.fit_transform(X_train)

from sklearn.linear_model import LinearRegression
Model_11 = LinearRegression()
Model_11.fit(PX_11_TR, y_train)

PX_11_TE  = poly.fit_transform(X_test)
y_hat_11 = Model_11.predict(PX_11_TE)

from sklearn.metrics import mean_squared_error

TE_Err_11 = mean_squared_error(y_test, y_hat_11)
TE_Err_11
# Out:
# 0.23657778702496807

# %%
from sklearn.preprocessing import PolynomialFeatures

poly=PolynomialFeatures(degree=13, include_bias=False)
PX_13_TR = poly.fit_transform(X_train)

from sklearn.linear_model import LinearRegression
Model_13 = LinearRegression()
Model_13.fit(PX_13_TR, y_train)

PX_13_TE  = poly.fit_transform(X_test)
y_hat_13 = Model_13.predict(PX_13_TE)

from sklearn.metrics import mean_squared_error

TE_Err_13 = mean_squared_error(y_test, y_hat_13)
TE_Err_13
# Out:
# 0.23045557248435067

# %%
from sklearn.preprocessing import PolynomialFeatures

poly=PolynomialFeatures(degree=30, include_bias=False)
PX_30_TR = poly.fit_transform(X_train)

from sklearn.linear_model import LinearRegression
Model_30 = LinearRegression()
Model_30.fit(PX_30_TR, y_train)

PX_30_TE  = poly.fit_transform(X_test)
y_hat_30 = Model_30.predict(PX_30_TE)

from sklearn.metrics import mean_squared_error

TE_Err_30 = mean_squared_error(y_test, y_hat_30)
TE_Err_30
# Out:
# 0.7513351356349774

# %%
from sklearn.preprocessing import PolynomialFeatures

poly=PolynomialFeatures(degree=100, include_bias=False)
PX_100_TR = poly.fit_transform(X_train)

from sklearn.linear_model import LinearRegression
Model_100 = LinearRegression()
Model_100.fit(PX_100_TR, y_train)

PX_100_TE  = poly.fit_transform(X_test)
y_hat_100 = Model_100.predict(PX_100_TE)

from sklearn.metrics import mean_squared_error

TE_Err_100 = mean_squared_error(y_test, y_hat_100)
TE_Err_100
# Out:
# 0.9094954508783535

# %%
print('1차 모델 : ', TE_Err_5)
print('5차 모델 : ', TE_Err_7)
print('9차 모델 : ', TE_Err_9)
print('11차 모델 : ', TE_Err_11)
print('13차 모델 : ', TE_Err_13)
print('30차 모델 : ', TE_Err_30)
print('100차 모델 : ', TE_Err_100)
# Out:
# 1차 모델 :  0.36825787122456405
# 5차 모델 :  0.2930399047903214
# 9차 모델 :  0.2930399047903214
# 11차 모델 :  0.23657778702496807
# 13차 모델 :  0.23045557248435067
# 30차 모델 :  0.7513351356349774
# 100차 모델 :  0.9094954508783535
