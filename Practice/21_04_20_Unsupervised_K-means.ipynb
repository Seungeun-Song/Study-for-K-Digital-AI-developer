# %%
import numpy as np
import pandas as pd

# %%
from keras.datasets import mnist
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# %%
X_train = X_train.reshape(-1, 28*28)
X_test = X_test.reshape(-1, 28*28)

X_train.shape, X_test.shape
# Out:
# ((60000, 784), (10000, 784))

# %%
url = 'https://raw.githubusercontent.com/rusita-ai/pyData/master/mnist_32.csv'
mnist_32 = pd.read_csv(url)
mnist_32.shape
# Out:
# (10000, 32)

# %%
mnist_32.head()
# Out:
#           0          1          2          3         4         5          6  \
# 0  3.688405   3.930005   9.707697  11.878195  8.254636  5.676317  17.008430
# 1  8.770631  13.023509   8.275418  10.167507  4.191549  8.799183   7.692517
# 2  3.612655   4.127336   6.994210  11.199030  4.834584  2.894823   7.723920
# 3  4.778088  11.318460  19.590998   9.894455  8.185436  5.662807   9.577927
# 4  4.581480   6.314673   9.630608   5.819597  4.213900  6.164255   1.878163
#
#            7         8          9  ...        22         23         24  \
# 0   5.514244 -0.829364   7.013071  ... -0.934536   6.870015  12.158235
# 1  14.583757 -0.964878   9.153512  ... -0.628069  16.332850  14.312974
# 2   3.293408  0.018939   2.376893  ... -0.839960   8.922295   3.176869
# 3  10.103026 -0.990062  15.396132  ... -0.950087   7.890187   9.783769
# 4   4.087563 -0.712614  15.693965  ... -0.781293   4.067109   4.883681
#
#           25         26         27        28        29        30         31
# 0  13.716932   8.344388  13.778448 -0.989779 -0.983739  4.144263  12.360807
# 1  10.023836   8.879703   4.838847 -0.999356 -0.976225  6.888207   5.912664
# 2   3.251928  10.095084   2.780117 -0.962890 -0.873302  4.892313   3.869293
# 3  11.231997   4.084829  17.978115 -0.999962 -0.998608  9.772373   9.696581
# 4  11.075063   8.700143  14.223484 -0.990151 -0.995499  8.750870  12.275040
#
# [5 rows x 32 columns]

# %%
from sklearn.cluster import KMeans

Clusters = KMeans(n_clusters=10, n_init=10, random_state=2045)
Clusters.fit(mnist_32)
# Out:
# KMeans(n_clusters=10, random_state=2045)

# %%
plt.imshow(X_test[0].reshape(28,28), cmap='gray')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,12))

for i in range(10):
    images = X_test[Clusters.labels_==i]
    for n in range(10):
        plt.subplot(10,10, i*10+n+1)
        plt.imshow(images[n].reshape(28,28), cmap='gray')
        plt.axis('off')
plt.show()
